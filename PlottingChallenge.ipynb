# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt('./Z1tofit.csv', delimiter=',')

# %% [markdown]
# ## Default

# %%
fig, ax = plt.subplots()
ax.plot(data[:,1], -data[:,2])
plt.show()

# %% [markdown]
# ### Can you reproduce something similar?
#
# <img src="https://github.com/mdmurbach/plotting-tutorial/blob/master/formatted.png?raw=true" />
#
# Important notes:
# - Make sure we have square axes!
# - Show data points
# - Add x and y labels with units
# - Change size of axes and tick labels
# - Add light background grid
# - Add text and arrow indicating frequency dependence
# - Change to scientific formating of axis ticks
